# %%
from estimate_entropy import meta_main, get_args
from tools import plot_entropy, plot_pdf
from os.path import join
import sys

# %% [markdown]
# ### First two experiments for $d=10,64$ in Section 3.1.1

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 1
args.iterations = 20
args.pdf = 'gaussian'
args.dimension = 10
args.reps = 5
args.lr = 1e-2

meta_main(args)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  2.87it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.60it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.5549
# INFO:estimate_entropy:  ERRROR:          0.3655
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.86it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.9685
# INFO:estimate_entropy:  ERRROR:          0.7791
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.24it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  15.9951
# INFO:estimate_entropy:  ERRROR:          1.8057
# INFO:estimate_entropy:Doing run 2...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  3.31it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.82it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.6236
# INFO:estimate_entropy:  ERRROR:          0.4342
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.98it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  15.0026
# INFO:estimate_entropy:  ERRROR:          0.8132
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.16it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  19.2531
# INFO:estimate_entropy:  ERRROR:          5.0638
# INFO:estimate_entropy:Doing run 3...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.44it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.79it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.5531
# INFO:estimate_entropy:  ERRROR:          0.3637
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.88it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.9740
# INFO:estimate_entropy:  ERRROR:          0.7846
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.14it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  25.0172
# INFO:estimate_entropy:  ERRROR:          10.8278
# INFO:estimate_entropy:Doing run 4...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           4
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.37it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.71it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.5351
# INFO:estimate_entropy:  ERRROR:          0.3457
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.68it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.8845
# INFO:estimate_entropy:  ERRROR:          0.6951
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.06it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  22.2043
# INFO:estimate_entropy:  ERRROR:          8.0149
# INFO:estimate_entropy:Doing run 5...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-10/rho-1.00
#       run_id:           5
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                10
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.34it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.55it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.6150
# INFO:estimate_entropy:  ERRROR:          0.4257
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.92it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  14.9466
# INFO:estimate_entropy:  ERRROR:          0.7572
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.23it/s]
# INFO:estimate_entropy:  True Entropy:    14.1894
# INFO:estimate_entropy:  Final Estimate:  24.1605
# INFO:estimate_entropy:  ERRROR:          9.9711
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 0.3870 ± 0.0359
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 0.7658 ± 0.0396
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 7.1367 ± 3.3210
# 'runs/pdf-gaussian/cubic-False/d-10/rho-1.00'

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 1
args.iterations = 20
args.pdf = 'gaussian'
args.dimension = 64
args.reps = 5
args.lr = 1e-2

meta_main(args)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:21<00:00,  1.07s/it]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:11<00:00,  1.75it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  94.6999
# INFO:estimate_entropy:  ERRROR:          3.8879
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.74it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  103.1150
# INFO:estimate_entropy:  ERRROR:          12.3030
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.72it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  130.0852
# INFO:estimate_entropy:  ERRROR:          39.2731
# INFO:estimate_entropy:Doing run 2...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:21<00:00,  1.10s/it]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:11<00:00,  1.81it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  94.3302
# INFO:estimate_entropy:  ERRROR:          3.5181
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.72it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  102.2239
# INFO:estimate_entropy:  ERRROR:          11.4119
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.19it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  127.1586
# INFO:estimate_entropy:  ERRROR:          36.3465
# INFO:estimate_entropy:Doing run 3...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:10<00:00,  1.83it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  94.4922
# INFO:estimate_entropy:  ERRROR:          3.6801
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.95it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  102.9292
# INFO:estimate_entropy:  ERRROR:          12.1172
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.99it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  123.1693
# INFO:estimate_entropy:  ERRROR:          32.3572
# INFO:estimate_entropy:Doing run 4...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-1.00
#       run_id:           4
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:20<00:00,  1.00s/it]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:10<00:00,  1.88it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  94.4263
# INFO:estimate_entropy:  ERRROR:          3.6143
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.05it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  102.5957
# INFO:estimate_entropy:  ERRROR:          11.7836
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.19it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  156.6527
# INFO:estimate_entropy:  ERRROR:          65.8407
# INFO:estimate_entropy:Doing run 5...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-1.00
#       run_id:           5
#       batchsize:        128
#       iterations:       20
#       epochs:           1
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              1.00
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/1 starting ...
# 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:12<00:00,  1.66it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  94.5904
# INFO:estimate_entropy:  ERRROR:          3.7784
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.64it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  102.8233
# INFO:estimate_entropy:  ERRROR:          12.0112
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.18it/s]
# INFO:estimate_entropy:  True Entropy:    90.8121
# INFO:estimate_entropy:  Final Estimate:  133.9356
# INFO:estimate_entropy:  ERRROR:          43.1236
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 3.6958 ± 0.1282
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 11.9254 ± 0.3068
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 43.3882 ± 11.7676
# 'runs/pdf-gaussian/cubic-False/d-64/rho-1.00'

# %% [markdown]
# ### Experiment depicted in Figure 1

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 5
args.iterations = 10
args.pdf = 'gaussian'
args.dimension = 64
args.rho = 0.5
args.rho_steps = 5
args.reps = 1
args.lr = 1e-2
args.run_id = 1

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-gaussian/cubic-False/d-64/rho-0.50
#       run_id:           1
#       batchsize:        128
#       iterations:       10
#       epochs:           5
#       kernel_samples:   128
#       d:                64
#       pdf:              gaussian
#       rho:              0.50
#       lr:               0.01
#
# INFO:estimate_entropy:Epoch 1/5 starting ...
# 100%|██████████| 10/10 [00:12<00:00,  1.26s/it]
# INFO:estimate_entropy:Epoch 2/5 starting ...
# 100%|██████████| 10/10 [00:12<00:00,  1.21s/it]
# INFO:estimate_entropy:Epoch 3/5 starting ...
# 100%|██████████| 10/10 [00:15<00:00,  1.54s/it]
# INFO:estimate_entropy:Epoch 4/5 starting ...
# 100%|██████████| 10/10 [00:15<00:00,  1.55s/it]
# INFO:estimate_entropy:Epoch 5/5 starting ...
# 100%|██████████| 10/10 [00:15<00:00,  1.52s/it]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
# INFO:estimate_entropy:  True Entropy:    2.0892
# INFO:estimate_entropy:  Final Estimate:  38.9794
# INFO:estimate_entropy:  ERRROR:          36.8902
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
# INFO:estimate_entropy:  True Entropy:    2.0892
# INFO:estimate_entropy:  Final Estimate:  67.4397
# INFO:estimate_entropy:  ERRROR:          65.3505
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# INFO:estimate_entropy:  True Entropy:    2.0892
# INFO:estimate_entropy:  Final Estimate:  86.2226
# INFO:estimate_entropy:  ERRROR:          84.1334
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 36.8902 ± 0.0000
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 65.3505 ± 0.0000
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 84.1334 ± 0.0000

# %% [markdown]
# ### Experiment depicted in Figure 2(left)

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 10
args.iterations = 20
args.pdf = 'triangle'
args.dimension = 1
args.plot = True
args.data_components = 10
args.lr = 1e-1
args.run_id = 1

log_dir = meta_main(args)
plot_pdf(join(log_dir, '1', 'pdfs_KNIFE_0.json'), show=True)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-1/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       20
#       epochs:           10
#       kernel_samples:   128
#       d:                1
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.10
#       data_components:  10
# INFO:estimate_entropy:Epoch 1/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.67it/s]
# INFO:estimate_entropy:Epoch 2/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.79it/s]
# INFO:estimate_entropy:Epoch 3/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.49it/s]
# INFO:estimate_entropy:Epoch 4/10 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  2.87it/s]
# INFO:estimate_entropy:Epoch 5/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.26it/s]
# INFO:estimate_entropy:Epoch 6/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.21it/s]
# INFO:estimate_entropy:Epoch 7/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.35it/s]
# INFO:estimate_entropy:Epoch 8/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.81it/s]
# INFO:estimate_entropy:Epoch 9/10 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  3.15it/s]
# INFO:estimate_entropy:Epoch 10/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.87it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:06<00:00,  3.19it/s]
# INFO:estimate_entropy:  True Entropy:    1.0462
# INFO:estimate_entropy:  Final Estimate:  1.1056
# INFO:estimate_entropy:  ERRROR:          0.0595
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.90it/s]
# INFO:estimate_entropy:  True Entropy:    1.0462
# INFO:estimate_entropy:  Final Estimate:  1.1518
# INFO:estimate_entropy:  ERRROR:          0.1057
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.96it/s]
# INFO:estimate_entropy:  True Entropy:    1.0462
# INFO:estimate_entropy:  Final Estimate:  2.6783
# INFO:estimate_entropy:  ERRROR:          1.6321
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 0.0595 ± 0.0000
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 0.1057 ± 0.0000
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 1.6321 ± 0.0000

# %% [markdown]
# ### Experiment depicted in Figure 2(right)

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 10
args.iterations = 20
args.pdf = 'triangle'
args.dimension = 8
args.data_components = 2
args.lr = 1e-3
args.reps = 3

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       20
#       epochs:           10
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:estimate_entropy:Epoch 1/10 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  3.13it/s]
# INFO:estimate_entropy:Epoch 2/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.85it/s]
# INFO:estimate_entropy:Epoch 3/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.76it/s]
# INFO:estimate_entropy:Epoch 4/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.72it/s]
# INFO:estimate_entropy:Epoch 5/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.76it/s]
# INFO:estimate_entropy:Epoch 6/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.69it/s]
# INFO:estimate_entropy:Epoch 7/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.79it/s]
# INFO:estimate_entropy:Epoch 8/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.55it/s]
# INFO:estimate_entropy:Epoch 9/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.49it/s]
# INFO:estimate_entropy:Epoch 10/10 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  3.31it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.13it/s]
# INFO:estimate_entropy:  True Entropy:    -0.0914
# INFO:estimate_entropy:  Final Estimate:  6.3824
# INFO:estimate_entropy:  ERRROR:          6.4737
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.36it/s]
# INFO:estimate_entropy:  True Entropy:    -0.0914
# INFO:estimate_entropy:  Final Estimate:  6.7534
# INFO:estimate_entropy:  ERRROR:          6.8448
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:07<00:00,  2.78it/s]
# INFO:estimate_entropy:  True Entropy:    -0.0914
# INFO:estimate_entropy:  Final Estimate:  15.7625
# INFO:estimate_entropy:  ERRROR:          15.8538
# INFO:estimate_entropy:Doing run 2...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       20
#       epochs:           10
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:estimate_entropy:Epoch 1/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.63it/s]
# INFO:estimate_entropy:Epoch 2/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.21it/s]
# INFO:estimate_entropy:Epoch 3/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.20it/s]
# INFO:estimate_entropy:Epoch 4/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.02it/s]
# INFO:estimate_entropy:Epoch 5/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.20it/s]
# INFO:estimate_entropy:Epoch 6/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.19it/s]
# INFO:estimate_entropy:Epoch 7/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.27it/s]
# INFO:estimate_entropy:Epoch 8/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.14it/s]
# INFO:estimate_entropy:Epoch 9/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.94it/s]
# INFO:estimate_entropy:Epoch 10/10 starting ...
# 100%|██████████| 20/20 [00:04<00:00,  4.24it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.16it/s]
# INFO:estimate_entropy:  True Entropy:    -0.1347
# INFO:estimate_entropy:  Final Estimate:  6.4782
# INFO:estimate_entropy:  ERRROR:          6.6129
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.36it/s]
# INFO:estimate_entropy:  True Entropy:    -0.1347
# INFO:estimate_entropy:  Final Estimate:  6.8014
# INFO:estimate_entropy:  ERRROR:          6.9361
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:04<00:00,  4.44it/s]
# INFO:estimate_entropy:  True Entropy:    -0.1347
# INFO:estimate_entropy:  Final Estimate:  13.6899
# INFO:estimate_entropy:  ERRROR:          13.8246
# INFO:estimate_entropy:Doing run 3...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       20
#       epochs:           10
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:estimate_entropy:Epoch 1/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.80it/s]
# INFO:estimate_entropy:Epoch 2/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.77it/s]
# INFO:estimate_entropy:Epoch 3/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.76it/s]
# INFO:estimate_entropy:Epoch 4/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.75it/s]
# INFO:estimate_entropy:Epoch 5/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.73it/s]
# INFO:estimate_entropy:Epoch 6/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.46it/s]
# INFO:estimate_entropy:Epoch 7/10 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  2.97it/s]
# INFO:estimate_entropy:Epoch 8/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.60it/s]
# INFO:estimate_entropy:Epoch 9/10 starting ...
# 100%|██████████| 20/20 [00:06<00:00,  3.21it/s]
# INFO:estimate_entropy:Epoch 10/10 starting ...
# 100%|██████████| 20/20 [00:05<00:00,  3.41it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:06<00:00,  3.29it/s]
# INFO:estimate_entropy:  True Entropy:    -1.2677
# INFO:estimate_entropy:  Final Estimate:  7.7545
# INFO:estimate_entropy:  ERRROR:          9.0222
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.90it/s]
# INFO:estimate_entropy:  True Entropy:    -1.2677
# INFO:estimate_entropy:  Final Estimate:  8.3939
# INFO:estimate_entropy:  ERRROR:          9.6616
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 20/20 [00:05<00:00,  3.77it/s]
# INFO:estimate_entropy:  True Entropy:    -1.2677
# INFO:estimate_entropy:  Final Estimate:  35.1837
# INFO:estimate_entropy:  ERRROR:          36.4514
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 7.3696 ± 1.1699
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 7.8141 ± 1.3069
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 22.0433 ± 10.2217

# %% [markdown]
# ### Experiment in supplementary material, B.2

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 20
args.iterations = 1000
args.pdf = 'triangle'
args.dimension = 20
args.data_components = 2
args.lr = 1e-3
args.reps = 10

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)

# %% [markdown]
# ### Original Experiment in Triangle Mixture

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 10
args.iterations = 200
args.pdf = 'triangle'
args.dimension = 1
args.plot = True
args.data_components = 10
args.lr = 1e-1
args.run_id = 1

log_dir = meta_main(args)
plot_pdf(join(log_dir, '1', 'pdfs_KNIFE_0.json'), show=True)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-1/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       200
#       epochs:           10
#       kernel_samples:   128
#       d:                1
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.10
#       data_components:  10
# INFO:estimate_entropy:Epoch 1/10 starting ...
# 100%|██████████| 200/200 [00:11<00:00, 17.19it/s]
# INFO:estimate_entropy:Epoch 2/10 starting ...
# 100%|██████████| 200/200 [00:10<00:00, 18.26it/s]
# INFO:estimate_entropy:Epoch 3/10 starting ...
# 100%|██████████| 200/200 [00:11<00:00, 16.85it/s]
# INFO:estimate_entropy:Epoch 4/10 starting ...
# 100%|██████████| 200/200 [00:10<00:00, 18.75it/s]
# INFO:estimate_entropy:Epoch 5/10 starting ...
# 100%|██████████| 200/200 [00:14<00:00, 14.21it/s]
# INFO:estimate_entropy:Epoch 6/10 starting ...
# 100%|██████████| 200/200 [00:08<00:00, 22.39it/s]
# INFO:estimate_entropy:Epoch 7/10 starting ...
# 100%|██████████| 200/200 [00:09<00:00, 21.91it/s]
# INFO:estimate_entropy:Epoch 8/10 starting ...
# 100%|██████████| 200/200 [00:09<00:00, 20.34it/s]
# INFO:estimate_entropy:Epoch 9/10 starting ...
# 100%|██████████| 200/200 [00:09<00:00, 21.92it/s]
# INFO:estimate_entropy:Epoch 10/10 starting ...
# 100%|██████████| 200/200 [00:08<00:00, 23.15it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:05<00:00, 36.34it/s]
# INFO:estimate_entropy:  True Entropy:    1.1628
# INFO:estimate_entropy:  Final Estimate:  1.2709
# INFO:estimate_entropy:  ERRROR:          0.1081
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:05<00:00, 37.87it/s]
# INFO:estimate_entropy:  True Entropy:    1.1628
# INFO:estimate_entropy:  Final Estimate:  1.2274
# INFO:estimate_entropy:  ERRROR:          0.0646
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 200/200 [00:05<00:00, 35.80it/s]
# INFO:estimate_entropy:  True Entropy:    1.1628
# INFO:estimate_entropy:  Final Estimate:  2.6088
# INFO:estimate_entropy:  ERRROR:          1.4460
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 0.1081 ± 0.0000
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 0.0646 ± 0.0000
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 1.4460 ± 0.0000

# %%
args = get_args([])
args.batchsize = 128
args.kernel_samples = 128
args.epochs = 20
args.iterations = 1000
args.pdf = 'triangle'
args.dimension = 8
args.data_components = 2
args.lr = 1e-3
args.reps = 3

log_dir = meta_main(args)
plot_entropy(join(log_dir, '1', 'run.json'), show=True)
# Out:
# INFO:estimate_entropy:Doing run 1...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           1
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:estimate_entropy:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [01:10<00:00, 14.12it/s]
# INFO:estimate_entropy:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [01:08<00:00, 14.68it/s]
# INFO:estimate_entropy:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [01:10<00:00, 14.22it/s]
# INFO:estimate_entropy:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [01:09<00:00, 14.33it/s]
# INFO:estimate_entropy:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [01:15<00:00, 13.30it/s]
# INFO:estimate_entropy:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [01:15<00:00, 13.18it/s]
# INFO:estimate_entropy:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [01:09<00:00, 14.37it/s]
# INFO:estimate_entropy:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [01:12<00:00, 13.71it/s]
# INFO:estimate_entropy:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [01:11<00:00, 14.08it/s]
# INFO:estimate_entropy:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [01:07<00:00, 14.77it/s]
# INFO:estimate_entropy:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [01:03<00:00, 15.68it/s]
# INFO:estimate_entropy:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 18.90it/s]
# INFO:estimate_entropy:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:51<00:00, 19.24it/s]
# INFO:estimate_entropy:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:51<00:00, 19.52it/s]
# INFO:estimate_entropy:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.86it/s]
# INFO:estimate_entropy:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [01:01<00:00, 16.15it/s]
# INFO:estimate_entropy:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.42it/s]
# INFO:estimate_entropy:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 19.03it/s]
# INFO:estimate_entropy:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.50it/s]
# INFO:estimate_entropy:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:51<00:00, 19.48it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:17<00:00, 58.23it/s]
# INFO:estimate_entropy:  True Entropy:    -6.8693
# INFO:estimate_entropy:  Final Estimate:  -1.7404
# INFO:estimate_entropy:  ERRROR:          5.1289
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:10<00:00, 92.76it/s]
# INFO:estimate_entropy:  True Entropy:    -6.8693
# INFO:estimate_entropy:  Final Estimate:  -3.0756
# INFO:estimate_entropy:  ERRROR:          3.7937
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:06<00:00, 143.42it/s]
# INFO:estimate_entropy:  True Entropy:    -6.8693
# INFO:estimate_entropy:  Final Estimate:  2.9737
# INFO:estimate_entropy:  ERRROR:          9.8430
# INFO:estimate_entropy:Doing run 2...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           2
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:estimate_entropy:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.47it/s]
# INFO:estimate_entropy:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:51<00:00, 19.53it/s]
# INFO:estimate_entropy:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:51<00:00, 19.34it/s]
# INFO:estimate_entropy:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [00:59<00:00, 16.76it/s]
# INFO:estimate_entropy:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:58<00:00, 16.97it/s]
# INFO:estimate_entropy:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:56<00:00, 17.79it/s]
# INFO:estimate_entropy:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.68it/s]
# INFO:estimate_entropy:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 19.19it/s]
# INFO:estimate_entropy:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.43it/s]
# INFO:estimate_entropy:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.22it/s]
# INFO:estimate_entropy:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.27it/s]
# INFO:estimate_entropy:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.73it/s]
# INFO:estimate_entropy:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.71it/s]
# INFO:estimate_entropy:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [00:59<00:00, 16.68it/s]
# INFO:estimate_entropy:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [00:55<00:00, 17.97it/s]
# INFO:estimate_entropy:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [01:12<00:00, 13.83it/s]
# INFO:estimate_entropy:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [01:01<00:00, 16.23it/s]
# INFO:estimate_entropy:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:57<00:00, 17.30it/s]
# INFO:estimate_entropy:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:57<00:00, 17.51it/s]
# INFO:estimate_entropy:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:57<00:00, 17.51it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:18<00:00, 53.87it/s]
# INFO:estimate_entropy:  True Entropy:    -1.6673
# INFO:estimate_entropy:  Final Estimate:  0.4584
# INFO:estimate_entropy:  ERRROR:          2.1257
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:09<00:00, 100.32it/s]
# INFO:estimate_entropy:  True Entropy:    -1.6673
# INFO:estimate_entropy:  Final Estimate:  1.7744
# INFO:estimate_entropy:  ERRROR:          3.4417
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:06<00:00, 143.18it/s]
# INFO:estimate_entropy:  True Entropy:    -1.6673
# INFO:estimate_entropy:  Final Estimate:  7.8594
# INFO:estimate_entropy:  ERRROR:          9.5267
# INFO:estimate_entropy:Doing run 3...
# INFO:estimate_entropy:
#     Settings:
#       CUDA:             False
#       debug:            False
#       logdir:           runs/pdf-triangle/cubic-False/d-8/rho-1.00
#       run_id:           3
#       batchsize:        128
#       iterations:       1000
#       epochs:           20
#       kernel_samples:   128
#       d:                8
#       pdf:              triangle
#       rho:              1.00
#       lr:               0.00
#       data_components:  2
# INFO:estimate_entropy:Epoch 1/20 starting ...
# 100%|██████████| 1000/1000 [01:11<00:00, 13.91it/s]
# INFO:estimate_entropy:Epoch 2/20 starting ...
# 100%|██████████| 1000/1000 [00:59<00:00, 16.76it/s]
# INFO:estimate_entropy:Epoch 3/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.67it/s]
# INFO:estimate_entropy:Epoch 4/20 starting ...
# 100%|██████████| 1000/1000 [01:00<00:00, 16.48it/s]
# INFO:estimate_entropy:Epoch 5/20 starting ...
# 100%|██████████| 1000/1000 [00:56<00:00, 17.66it/s]
# INFO:estimate_entropy:Epoch 6/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.82it/s]
# INFO:estimate_entropy:Epoch 7/20 starting ...
# 100%|██████████| 1000/1000 [00:59<00:00, 16.69it/s]
# INFO:estimate_entropy:Epoch 8/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 19.03it/s]
# INFO:estimate_entropy:Epoch 9/20 starting ...
# 100%|██████████| 1000/1000 [00:54<00:00, 18.29it/s]
# INFO:estimate_entropy:Epoch 10/20 starting ...
# 100%|██████████| 1000/1000 [01:00<00:00, 16.41it/s]
# INFO:estimate_entropy:Epoch 11/20 starting ...
# 100%|██████████| 1000/1000 [00:59<00:00, 16.77it/s]
# INFO:estimate_entropy:Epoch 12/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 19.21it/s]
# INFO:estimate_entropy:Epoch 13/20 starting ...
# 100%|██████████| 1000/1000 [01:00<00:00, 16.45it/s]
# INFO:estimate_entropy:Epoch 14/20 starting ...
# 100%|██████████| 1000/1000 [01:09<00:00, 14.46it/s]
# INFO:estimate_entropy:Epoch 15/20 starting ...
# 100%|██████████| 1000/1000 [01:00<00:00, 16.63it/s]
# INFO:estimate_entropy:Epoch 16/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.72it/s]
# INFO:estimate_entropy:Epoch 17/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 19.20it/s]
# INFO:estimate_entropy:Epoch 18/20 starting ...
# 100%|██████████| 1000/1000 [00:51<00:00, 19.58it/s]
# INFO:estimate_entropy:Epoch 19/20 starting ...
# 100%|██████████| 1000/1000 [00:52<00:00, 19.08it/s]
# INFO:estimate_entropy:Epoch 20/20 starting ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.85it/s]
# INFO:estimate_entropy:Finished training.
# INFO:estimate_entropy:KNIFE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:19<00:00, 52.34it/s]
# INFO:estimate_entropy:  True Entropy:    -0.6042
# INFO:estimate_entropy:  Final Estimate:  -0.1564
# INFO:estimate_entropy:  ERRROR:          0.4477
# INFO:estimate_entropy:Schraudolph: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:10<00:00, 97.48it/s]
# INFO:estimate_entropy:  True Entropy:    -0.6042
# INFO:estimate_entropy:  Final Estimate:  0.6500
# INFO:estimate_entropy:  ERRROR:          1.2542
# INFO:estimate_entropy:DoE: final evaluation on fresh dataset...
# 100%|██████████| 1000/1000 [00:08<00:00, 120.08it/s]
# INFO:estimate_entropy:  True Entropy:    -0.6042
# INFO:estimate_entropy:  Final Estimate:  2.0931
# INFO:estimate_entropy:  ERRROR:          2.6972
# INFO:estimate_entropy:FINAL:
# INFO:estimate_entropy:KNIFE:
# INFO:estimate_entropy:  error 1: 2.5675 ± 1.9364
# INFO:estimate_entropy:Schraudolph:
# INFO:estimate_entropy:  error 1: 2.8299 ± 1.1234
# INFO:estimate_entropy:DoE:
# INFO:estimate_entropy:  error 1: 7.3557 ± 3.2965
